# %%
import pandas as pd
import numpy as np
from pathlib import Path
import json
import os
import collections
import matplotlib.pyplot as plt
from pathlib import Path
from imageio import imread, imwrite
import cv2
import sys
sys.path.insert(0, "../../SemanticStyleGAN")
from data.preprocess_idd import process_img as process_img_2
#Labels are present at https://github.com/AutoNUE/public-code/blob/master/helpers/anue_labels.py

# %%
dataset_path ="/data/public/idd-segmentation/IDD_Segmentation"
# d1=dataset_path+"/IDD_Segmentation"
# d2=dataset_path+"/idd20kII"
# f1 = sum([len(files) for r, d, files in os.walk(d1)])
# f2 = sum([len(files) for r, d, files in os.walk(d2)])
# print(f1)
# print(f2)

# %%
## Identify a certain class by Edtiting it's pixel
dataset_path="/data/public/idd-segmentation/IDD_Segmentation/"
filepath="/data/public/idd-segmentation/IDD_Segmentation/gtFine/train/2/116356_gtFine_labelids.png"

edited_class=0
for edited_class in np.arange(0,36):
    image = imread(filepath)
    image[image==edited_class]=200
    cv2.imwrite(f"./data_idd/sample_img_{list(labels)[edited_class]}_{edited_class}.png",image)
# Out:
# /tmp/ipykernel_140531/1636446265.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(filepath)

# %%
count=0
maxi=0
for subdir, _, files in os.walk(dataset_path):
    for file in files:
        if "labelids" in file:
            count+=1
print(count)
# Out:
# 7974

# %% [markdown]
# #### Processing the whole Dataset

# %%
###Searching all the dataset for images that contains a certain class.
def process_img(dataset_path, output_prefix):
    accum = 0
    files_count = sum([len(files) for r, d, files in os.walk(dataset_path)])
    for subdir, _, files in os.walk(dataset_path):
        # The dataset has to be of format */gtFine/train/*/*.png

        ##Creation of the same directories again.
        if subdir.split("/")[-3] == "gtFine":
            output_dir = "/".join(subdir.split("/")[-3:]).replace(
                "gtFine", "gtFine_preprocessed"
            )
            output_dir = Path(output_prefix + output_dir)
            # print(output_dir)
            #output_dir.mkdir(parents=True, exist_ok=True)##TODO: Remove later
        for file in files:
            
            #if accum % 1000 == 0:
               # print(f"Done with {accum}/{files_count} images")
            
            if "labelids" not in file:
                continue
            accum += 1
            filepath = subdir + os.sep + file
            output_path_1 = str(output_dir) + os.sep +str(accum)+ "animal" +file
            output_path_2 = str(output_dir) + os.sep + str(accum)+"obst_fall"+file
            output_path_3 = str(output_dir) + os.sep + str(accum)+"back_fall"+file
            image = imread(filepath)
            image_animal=image.copy()
            image_obst_fallback=image.copy()
            image_back_fallback=image.copy()
            image_animal[image_animal==7]=200
            image_obst_fallback[image_obst_fallback==28]=200
            image_back_fallback[image_back_fallback==34]=200
            # preprocessed_image = simplify_image_labels(image, False)
            if (image==7).mean() >0:
                 print(output_path_3)
                 output_dir.mkdir(parents=True, exist_ok=True)
                 cv2.imwrite(output_path_1, image_animal)
                 #cv2.imwrite(output_path_2, image_obst_fallback)
                 #cv2.imwrite(output_path_3, image_back_fallback)
    print(f"All files has been processed")

# %%
dataset_path ="/data/public/idd-segmentation/IDD_Segmentation"
process_img(dataset_path,"./data_idd/output/")
# Out:
# /tmp/ipykernel_140531/2728012536.py:27: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread
a href='vscode-notebook-cell://ssh-remote%2Blogin1/usrhomes/g013/SemanticStyleGAN/notebooks/IDD_exploration.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a> output_path_3 = str(output_dir) + os.sep + str(accum)+"back_fall"+file
# ---> <a href='vscode-notebook-cell://ssh-remote%2Blogin1/usrhomes/g013/SemanticStyleGAN/notebooks/IDD_exploration.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a> image = imread(filepath)
#      <a href='vscode-notebook-cell://ssh-remote%2Blogin1/usrhomes/g013/SemanticStyleGAN/notebooks/IDD_exploration.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> image_animal=image.copy()
#      <a href='vscode-notebook-cell://ssh-remote%2Blogin1/usrhomes/g013/SemanticStyleGAN/notebooks/IDD_exploration.ipynb#X16sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a> image_obst_fallback=image.copy()
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/__init__.py:97, in imread(uri, format, **kwargs)
#      68 """imread(uri, format=None, **kwargs)
#      69
#      70 Reads an image from the specified file. Returns a numpy array, which
#    (...)
#      86     to see what arguments are available for a particular format.
#      87 """
#      89 warnings.warn(
#      90     "Starting with ImageIO v3 the behavior of this function will switch to that of"
#      91     " iio.v3.imread. To keep the current behavior (and make this warning disappear)"
#    (...)
#      94     stacklevel=2,
#      95 )
# ---> 97 return imread_v2(uri, format=format, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/v2.py:201, in imread(uri, format, **kwargs)
#     198 imopen_args["legacy_mode"] = True
#     200 with imopen(uri, "ri", **imopen_args) as file:
# --> 201     return file.read(index=0, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/core/legacy_plugin_wrapper.py:147, in LegacyPlugin.read(self, index, **kwargs)
#     144     img = np.stack([im for im in self.iter(**kwargs)])
#     145     return img
# --> 147 reader = self.legacy_get_reader(**kwargs)
#     148 return reader.get_data(index)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/core/legacy_plugin_wrapper.py:116, in LegacyPlugin.legacy_get_reader(self, **kwargs)
#     113     return self._format.get_reader(self._request)
#     115 self._request.get_file().seek(0)
# --> 116 return self._format.get_reader(self._request)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/core/format.py:220, in Format.get_reader(self, request)
#     216 if select_mode not in self.modes:
#     217     raise RuntimeError(
#     218         f"Format {self.name} cannot read in {request.mode.image_mode} mode"
#     219     )
# --> 220 return self.Reader(self, request)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/core/format.py:311, in Format._BaseReaderWriter.__init__(self, format, request)
#     309 self._request = request
#     310 # Open the reader/writer
# --> 311 self._open(**self.request.kwargs.copy())
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:394, in PNGFormat.Reader._open(self, pilmode, as_gray, ignoregamma)
#     393 def _open(self, pilmode=None, as_gray=False, ignoregamma=True):
# --> 394     return PillowFormat.Reader._open(self, pilmode=pilmode, as_gray=as_gray)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:300, in PillowFormat.Reader._open(self, pilmode, as_gray)
#     298 if self._im.palette and self._im.palette.dirty:
#     299     self._im.palette.rawmode_saved = self._im.palette.rawmode
# --> 300 pil_try_read(self._im)
#     301 # Store args
#     302 self._kwargs = dict(
#     303     as_gray=as_gray, is_gray=_palette_is_grayscale(self._im)
#     304 )
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/imageio/plugins/pillow_legacy.py:654, in pil_try_read(im)
#     651 def pil_try_read(im):
#     652     try:
#     653         # this will raise an IOError if the file is not readable
# --> 654         im.getdata()[0]
#     655     except IOError as e:
#     656         site = "http://pillow.readthedocs.io/en/latest/installation.html"
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/PIL/Image.py:1294, in Image.getdata(self, band)
#    1276 def getdata(self, band=None):
#    1277     """
#    1278     Returns the contents of this image as a sequence object
#    1279     containing pixel values.  The sequence object is flattened, so
#    (...)
#    1291     :returns: A sequence-like object.
#    1292     """
# -> 1294     self.load()
#    1295     if band is not None:
#    1296         return self.im.getband(band)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/PIL/ImageFile.py:253, in ImageFile.load(self)
#     247         raise OSError(
#     248             "image file is truncated "
#     249             f"({len(b)} bytes not processed)"
#     250         )
#     252 b = b + s
# --> 253 n, err_code = decoder.decode(b)
#     254 if n < 0:
#     255     break
#
# KeyboardInterrupt:

# %%
### Actual call to the main algorithm
dataset_path ="/data/public/idd-segmentation/IDD_Segmentation/gtFine"
process_img_2(dataset_path,"./data_idd/output/")
# Out:
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine']
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train']
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '138']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '2']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '95']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '71']
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '145']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 1000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '49']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '177']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '100']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 2000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '34']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '43']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '121']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '156']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 3000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '86']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '68']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '164']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '57']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 4000/39870 images
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '20']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '163']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '151']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 5000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '126']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '65']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '81']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '39']
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 6000/39870 images
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '107']
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '170']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '44']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '5']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 7000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '98']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '76']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '142']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '135']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 8000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '146']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '131']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '72']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '78']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '96']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 9000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '1']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 10000/39870 images
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '40']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '37']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '174']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 11000/39870 images
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '128']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '85']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '16']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 12000/39870 images
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '155']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '122']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '59']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 13000/39870 images
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '110']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '53']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '29']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 14000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '160']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '117']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '23']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '158']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 15000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '11']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '125']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '152']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 16000/39870 images
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '30']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '173']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '104']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '136']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 17000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '141']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '75']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '91']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '6']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 18000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '32']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 19000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '45']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '171']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '106']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '38']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '143']
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '77']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 20000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '93']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '168']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 21000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '162']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '115']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '56']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '80']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 22000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '64']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '127']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '87']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 23000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '69']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '63']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 24000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '157']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 25000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '118']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '26']
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '144']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '133']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '9']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '70']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 26000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '94']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 27000/39870 images
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '139']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '42']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '101']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '176']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '48']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 28000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '178']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '46']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 29000/39870 images
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '31']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '7']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '90']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '140']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 30000/39870 images
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '137']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '116']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '28']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '124']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '10']
# in
# in
# in
# in
# in
# in
# Done with 31000/39870 images
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '154']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '60']
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '84']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '25']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '52']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 32000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '166']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '0']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '79']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '130']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 33000/39870 images
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '108']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '175']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '102']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '36']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 34000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'train', '41']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val']
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '148']
# in
# in
# in
# in
# in
# in
# Done with 35000/39870 images
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '62']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '119']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '18']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '132']
# in
# in
# in
# in
# in
# in
# Done with 36000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '24']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '167']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '88']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '66']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '47']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '3']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 37000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '181']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '21']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '150']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '51']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 38000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '149']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '147']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '89']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '67']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# Done with 39000/39870 images
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '153']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '17']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# ['', 'data', 'public', 'idd-segmentation', 'IDD_Segmentation', 'gtFine', 'val', '172']
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# in
# All files has been processed

# %%
from glob import glob

# %%
path="/data/public/idd-segmentation/IDD_Segmentation/leftImg8bit"
glob(f"{path}/(?!test)/**/*.png", recursive=True)
# Out:
# []
